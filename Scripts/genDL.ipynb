# %%
# !pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 2.9 MB/s
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.0-py3-none-any.whl (213 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.21.6)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3160889 sha256=2a165dc9dc8d1faea6301e822f7de7dad647d5375d9a8b4432dcbaa47580c57c
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
from urllib.request import urlopen
import socket
import numpy as np
import pandas as pd
import re
import fasttext.util
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #Socrata API

# %% [markdown]
# ## Download metadata sets

# %%
def get_metadata(category, pages, limit, offset):
  url = 'http://api.us.socrata.com/api/catalog/v1?only=datasets&categories='+category
  metaDL = []
  for i in range(pages):
    # offset = i * limit + init_offset
    response = urlopen(url+'&offset='+str(offset)+'&limit='+str(limit))
    metadata_set = json.loads(response.read())['results']

    for metadata in metadata_set:
        if( len(metadata['resource']['columns_field_name']) > 0 
            and len(metadata['classification']['domain_tags']) > 0 
            and ('Text' in metadata['resource']['columns_datatype']) ):
            metaDL.append(metadata)

    offset += limit
  
  print("MetaDL Size: %d"%len(metaDL))
  return metaDL

# %%
keys = ['Finance', 'Social+Services', 'Demographics', 'Infrastructure', 'Health', 'Environment', 'Public+Safety', 'Education', 'Economy', 'Transportation']
for key in keys:
  metaDL = get_metadata(key, 1, 30000, 0)
# Out:
# MetaDL Size: 3057
# MetaDL Size: 1174
# MetaDL Size: 2796
# MetaDL Size: 2371
# MetaDL Size: 2149
# MetaDL Size: 2090
# MetaDL Size: 1856
# MetaDL Size: 1749
# MetaDL Size: 1766
# MetaDL Size: 1624

# %% [markdown]
# ## Download data sets

# %% [markdown]
# ##FastText

# %%
# fasttext.util.download_model('en', if_exists='ignore')
# ft_model = fasttext.load_model('/content/drive/MyDrive/Data Lake/cc.en.300.bin')
#Or manually download from https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
ft_model = fasttext.load_model('/content/drive/MyDrive/Data Lake/cc.en.100.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
ft_model.get_nearest_neighbors('man')
# Out:
# [(0.8106521368026733, 'boy'),
#  (0.7907684445381165, 'woman'),
#  (0.7292563319206238, 'man--he'),
#  (0.7282201051712036, 'gentleman'),
#  (0.7252405285835266, 'family-man'),
#  (0.7247761487960815, 'person'),
#  (0.7210360765457153, 'man-child'),
#  (0.7201767563819885, 'father'),
#  (0.7127508521080017, 'policeman'),
#  (0.7111547589302063, 'man--a')]

# %%
ft_model.get_word_vector('man').shape
# Out:
# (100,)

# %% [markdown]
# ##Download and process data sets

# %%
def get_data(metadata, limit = 100):

  url = "http://" + metadata['metadata']['domain'] + "/resource/" + metadata['resource']['id'] + ".json?$limit="+str(limit)

  #FILTER COLUMNS WITH TEXT DATA TYPE
  types = np.array(metadata['resource']['columns_datatype'])
  columns = np.array(metadata['resource']['columns_field_name'])
  columns = columns[np.where(types == 'Text')]

  url += "&$select="+",".join(columns)
  # print(url)

  data = pd.read_json(url)

  # REMOVE COLUMNS WITHOUT TEXT
  data = data.applymap(lambda s : str(s).lower()) #LOWERCASE
  data = data.applymap(lambda s : re.sub(r'[^a-z\s]', '', s)) #REMOVE NO-LETTERS
  data = data.applymap(lambda s : re.sub(r'\s+', ' ', s)) #REMOVE EXTRA BLANK SPACES

  data.replace('', float('NaN'), inplace = True) # '' -> NaN
  data.dropna(how='all', axis=1, inplace=True) # Remove columns only filled with NaN

  return data

# %%
def build_DL(sizeDL, category, limit, black_list, ft_model):
  # print(limit)
  # pages = int(10*sizeDL/limit)
  pages = 1
  metaDL = get_metadata(category, pages, limit, 0)
  DL = list()
  vec_DL = list()
  i = 0
  while len(DL) < sizeDL and i < len(metaDL):
      metadata = metaDL[i]
      i += 1
      try:
          str_id = metadata['metadata']['domain'] + "/" + metadata['resource']['id']
          if str_id in black_list :
            raise Exception('Duplicated Dataset')

          data = get_data(metadata)

          #EXTRACT TOPIC VECTORS
          data_vec = data.applymap(lambda w : ft_model.get_word_vector(str(w)))
          data_vec = data_vec.sum(axis = 0)
          #REMOVE COLUMNS WITH ZERO VECTOR REPRESENTATION
          drop_columns = list()
          for col in data_vec.index:
            if data_vec[col].sum() == 0:
              drop_columns.append(col)
          data_vec = data_vec.drop(drop_columns)

          if data_vec.shape[0] == 0:
            raise Exception('Empty Dataset')
            
          black_list.append(str_id)
          DL.append(data)
          vec_DL.append(data_vec)

          # print(len(DL))

      except Exception as e: 
          # print(e)
          i -= 1
          metaDL.pop(i)

  metaDL = metaDL[:sizeDL]
  return metaDL, DL, vec_DL, black_list

# %%
def syntactic_norm(metaDL, ft_model):
  stemmer = nltk.stem.LancasterStemmer()
  #COLLECTING THE DL TAGS INDEXING DATASETS
  tagsDL = dict()
  raw_tags = set()
  for i in range(len(metaDL)):
    tags = metaDL[i]['classification']['domain_tags']
    raw_tags.update(tags)
    for text in tags:
      text = re.sub('\W+',' ', text) #REMOVE PUNCTUATION
      tokens = word_tokenize(text) #SPLIT THE TEXT IN WORDS
      for t in tokens:
        if not t in stopwords.words(): #IGNORE STOP WORDS
          t = stemmer.stem(t) #STEMMING (Syntactic Normalization)
          datatypes = np.array(metaDL[i]['resource']['columns_datatype'])
          num_text_cols = np.sum(datatypes == 'Text')

          if t not in tagsDL:
            tagsDL[t] = [{i}, num_text_cols, ft_model.get_word_vector(t)]
          elif i not in tagsDL[t][0]:
            tagsDL[t][0].add(i)
            tagsDL[t][1] += num_text_cols

  print('Raw tags space size: %d'%len(raw_tags))
  print('Tags space after Syntatic Norm.: %d'%len(tagsDL))

  return tagsDL

def semantic_norm(metaDL, tagsDL):
  #Semantic Normalization
  keys = list( np.sort( list( tagsDL.keys() ) ) )
  groups = [ [ keys.pop(0) ] ]
  i = 0
  while len(keys) > 0 :
    next_tag = keys[i]
    vec = tagsDL[next_tag][2]
    flag = True
    for k in groups[-1]:
      vec_k = tagsDL[k][2]
      similarity = np.dot(vec, vec_k) / ( np.linalg.norm(vec) * np.linalg.norm(vec_k) )
      if similarity <= 0.9 :
        flag = False
        break
    if flag :
      groups[-1].append(next_tag)
      keys.pop(i)
    else:
      i = (i + 1) % len(keys)
      if i == 0:
        groups.append( [ keys.pop(0) ] )

  for i in range( len(groups) ) :
    group = groups[i]
    tagsDL[ group[0] ].pop() #REMOVE VECTOR
    if len(group) > 1 :
      meta_tag = group[0]
      for j in range(1, len(group)):
        tag_j = group[j]

        domain_diff = 0
        intersect = tagsDL[meta_tag][0] & tagsDL[tag_j][0]
        for d in list(intersect):
          datatypes = np.array(metaDL[d]['resource']['columns_datatype'])
          domain_diff += np.sum(datatypes == 'Text')

        tagsDL[meta_tag][0].update( tagsDL[tag_j][0] )
        tagsDL[meta_tag][1] += tagsDL[tag_j][1] - domain_diff
        tagsDL.pop(tag_j)

  print('Tags space after Semantic Norm.: %d'%len(tagsDL))

  return tagsDL

def structural_norm(tagsDL):
  # Structural Normalization
  #   1-subsumed with support <= 20
  redundants = set()
  keys = list( tagsDL.keys() )
  for i in range(len(keys)):
    domain_i = tagsDL[keys[i]][0]
    for j in range(i+1, len(keys)):
      domain_j = tagsDL[keys[j]][0]
      if domain_j.issubset( domain_i ) and tagsDL[keys[j]][1] <= 20 :
        redundants.add(keys[j])
        # print(keys[i] + " - " + keys[j] )
        # print(str(domain_i) + " - " + str(domain_j) )
      elif domain_i.issubset( domain_j ) and tagsDL[keys[i]][1] <= 20 :
        redundants.add(keys[i])
        # print(keys[j] + " - " + keys[i] )
        # print(str(domain_j) + " - " + str(domain_i) )
        break
  
  print('1-redundant tags: %d'%len(redundants))

  for key in list(redundants):
    tagsDL.pop(key)

  #   2-subsumed with support <= 20
  redundants = set()
  black_list = list()
  keys = list( tagsDL.keys() )

  for i in range(len(keys)) :
    if tagsDL[keys[i]][1] <= 20 and keys[i] not in black_list :
      domain_i = tagsDL[keys[i]][0]
      for j in range(len(keys)) :
        if keys[j] != keys[i] and keys[j] not in redundants:
          domain_j = tagsDL[keys[j]][0]
          for k in range(len(keys)) :
            domain_k = tagsDL[keys[k]][0]
            if keys[k] != keys[i] and keys[k] not in redundants and domain_i.issubset( domain_j | domain_k ):
              redundants.add(keys[i])
              black_list.append(keys[j])
              black_list.append(keys[k])

  
  print('2-redundant tags: %d'%len(redundants))

  for key in list(redundants):
    tagsDL.pop(key)

  print('Tags space after Structural Norm.: %d'%len(tagsDL))

  return tagsDL

def process_metadata(metaDL, ft_model):
  tagsDL = syntactic_norm(metaDL, ft_model)
  tagsDL = semantic_norm(metaDL, tagsDL)
  tagsDL = structural_norm(tagsDL)

  # print(tagsDL)

  tags_id = list()
  keys = list( tagsDL.keys() )
  for i in range( len(metaDL) ) :
    tags_id.append( list() )
    for k in range( len(keys) ) :
      if i in tagsDL[keys[k]][0] :
        tags_id[-1].append(k)
  return tags_id, len(keys)

# %%
def generate_instance(DL, vec_DL, metaDL, sizeDL, ft_model):
  tagsDL, num_tags = process_metadata(metaDL, ft_model)
  vecDL = str(sizeDL) + ' ' + str(num_tags) + ' '+ str(ft_model.get_dimension()) +'\n'
  DL_json = {'resource': list()}
  num_columns = 0

  for i in range(len(DL)) :
    data = DL[i]
    tags = tagsDL[i]
    #GENERATE JSON VERSION
    data_json = data.to_dict(orient="records")
    DL_json['resource'].append(data_json)

    data = vec_DL[i]

    num_columns += data.shape[0]
    vecDL += '100 ' + str(data.shape[0]) + ' ' + str(len(tags)) + '\n'
    vecDL += str(tags).replace('[', '').replace(']', '').replace(',', ' ') + '\n'
    for col in range(data.shape[0]):
      vecDL += '0\n' # No tags on columns
      vecDL += str(list(data[col])).replace('[', '').replace(']', '').replace(',', ' ')
      vecDL += '\n'
    
  print("Total number of columns: %d"%num_columns)
  return vecDL, DL_json

# %%
def generate_output_instances(final_sizeDL) :
  keys = ['Finance', 'Social+Services', 'Demographics', 'Infrastructure', 'Health', 'Environment', 'Public+Safety', 'Education', 'Economy', 'Transportation']
  # offsets = dict(zip(keys, 10*[0]))
  black_list = list()
  limit = 5000

  socket.setdefaulttimeout(10)

  # category_sets = [['Education']]
  # for i in range(1, len(keys)) :
  #   category_sets.append(category_sets[-1].copy())
  #   category_sets[-1].append(keys[i])

  category_sets = list()
  category_sets.append(keys[0:1])
  category_sets.append(keys[1:3])
  category_sets.append(keys[3:6])
  category_sets.append(keys[6:])

  for i in range(5, -1, -1) :
    category_sets.append(category_sets[-1].copy())
    category_sets[-1].append(keys[i])

  print(category_sets)

  for categories in category_sets :
    DL = list()
    vec_DL = list()
    metaDL = list()
    # print(categories)
    for i in range(len(categories)) :
      category = categories[i]
      sizeDL = int( final_sizeDL / len(categories) )
      sizeDL += ( i < ( final_sizeDL % len(categories) ) )
      add_metaDL, add_DL, add_vec_DL, black_list = build_DL(sizeDL, category, limit, black_list, ft_model)
      print(category + " : %d"%len(add_DL))
      metaDL += add_metaDL
      DL += add_DL
      vec_DL += add_vec_DL

    print("DL size : %d"%len(metaDL))

    vecDL, DL_json = generate_instance(DL, vec_DL, metaDL, final_sizeDL, ft_model)
    metaDL = { 'resource' : metaDL }
    path = '/content/drive/MyDrive/Data Lake/Socrata/'

    suffix = '-'+str(final_sizeDL)+'-'+str(len(categories))
    with open(path + 'Data/metaDL'+suffix+'.json', 'w', encoding='utf-8') as f:
        json.dump(metaDL, f, ensure_ascii=False, indent=4)

    with open(path + 'Data/DL'+suffix+'.json', 'w', encoding='utf-8') as f:
        json.dump(DL_json, f, ensure_ascii=True, indent = 4)

    text_file = open(path + 'Processed_Data/topic_vectors'+suffix+'.txt', "w")
    text_file.write(vecDL)
    text_file.close()

# %%
generate_output_instances(500)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3057
# /usr/local/lib/python3.7/dist-packages/dateutil/parser/_parser.py:1212: UnknownTimezoneWarning: tzname M identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# Finance : 500
# DL size : 500
# Raw tags space size: 1613
# Tags space after Syntatic Norm.: 1215
# Tags space after Semantic Norm.: 1195
# 1-redundant tags: 667
# 2-redundant tags: 45
# Tags space after Structural Norm.: 483
# Total number of columns: 3466
# MetaDL Size: 1174
# Social+Services : 250
# MetaDL Size: 2796
# Demographics : 250
# DL size : 500
# Raw tags space size: 1851
# Tags space after Syntatic Norm.: 1446
# Tags space after Semantic Norm.: 1418
# 1-redundant tags: 858
# 2-redundant tags: 54
# Tags space after Structural Norm.: 506
# Total number of columns: 3628
# MetaDL Size: 2371
# Infrastructure : 167
# MetaDL Size: 2149
# Health : 167
# MetaDL Size: 2090
# Environment : 166
# DL size : 500
# Raw tags space size: 1891
# Tags space after Syntatic Norm.: 1484
# Tags space after Semantic Norm.: 1466
# 1-redundant tags: 811
# 2-redundant tags: 44
# Tags space after Structural Norm.: 611
# Total number of columns: 3896
# MetaDL Size: 1856
# Public+Safety : 125
# MetaDL Size: 1749
# Education : 125
# MetaDL Size: 1766
# Economy : 125
# MetaDL Size: 1624
# Transportation : 125
# DL size : 500
# Raw tags space size: 1782
# Tags space after Syntatic Norm.: 1350
# Tags space after Semantic Norm.: 1329
# 1-redundant tags: 793
# 2-redundant tags: 36
# Tags space after Structural Norm.: 500
# Total number of columns: 4572
# MetaDL Size: 1856
# Public+Safety : 100
# MetaDL Size: 1749
# Education : 100
# MetaDL Size: 1766
# Economy : 100
# MetaDL Size: 1624
# Transportation : 100
# MetaDL Size: 2090
# Environment : 100
# DL size : 500
# Raw tags space size: 1920
# Tags space after Syntatic Norm.: 1494
# Tags space after Semantic Norm.: 1469
# 1-redundant tags: 855
# 2-redundant tags: 40
# Tags space after Structural Norm.: 574
# Total number of columns: 4303
# MetaDL Size: 1856
# Public+Safety : 84
# MetaDL Size: 1749
# Education : 84
# MetaDL Size: 1766
# Economy : 83
# MetaDL Size: 1624
# Transportation : 83
# MetaDL Size: 2090
# Environment : 83
# MetaDL Size: 2149
# Health : 83
# DL size : 500
# Raw tags space size: 1756
# Tags space after Syntatic Norm.: 1297
# Tags space after Semantic Norm.: 1279
# 1-redundant tags: 653
# 2-redundant tags: 42
# Tags space after Structural Norm.: 584
# Total number of columns: 4255
# MetaDL Size: 1856
# Public+Safety : 72
# MetaDL Size: 1749
# Education : 72
# MetaDL Size: 1766
# Economy : 72
# MetaDL Size: 1624
# Transportation : 71
# MetaDL Size: 2090
# Environment : 71
# MetaDL Size: 2149
# Health : 71
# MetaDL Size: 2371
# Infrastructure : 71
# DL size : 500
# Raw tags space size: 1724
# Tags space after Syntatic Norm.: 1283
# Tags space after Semantic Norm.: 1261
# 1-redundant tags: 664
# 2-redundant tags: 50
# Tags space after Structural Norm.: 547
# Total number of columns: 4453
# MetaDL Size: 1856
# Public+Safety : 63
# MetaDL Size: 1749
# Education : 63
# MetaDL Size: 1766
# Economy : 63
# MetaDL Size: 1624
# Transportation : 63
# MetaDL Size: 2090
# Environment : 62
# MetaDL Size: 2149
# Health : 62
# MetaDL Size: 2371
# Infrastructure : 62
# MetaDL Size: 2796
# Demographics : 62
# DL size : 500
# Raw tags space size: 1941
# Tags space after Syntatic Norm.: 1496
# Tags space after Semantic Norm.: 1474
# 1-redundant tags: 865
# 2-redundant tags: 46
# Tags space after Structural Norm.: 563
# Total number of columns: 3613
# MetaDL Size: 1856
# Public+Safety : 56
# MetaDL Size: 1749
# Education : 56
# MetaDL Size: 1766
# Economy : 56
# MetaDL Size: 1624
# Transportation : 56
# MetaDL Size: 2090
# Environment : 56
# MetaDL Size: 2149
# Health : 55
# MetaDL Size: 2371
# Infrastructure : 55
# MetaDL Size: 2796
# Demographics : 55
# MetaDL Size: 1174
# Social+Services : 55
# DL size : 500
# Raw tags space size: 1897
# Tags space after Syntatic Norm.: 1458
# Tags space after Semantic Norm.: 1435
# 1-redundant tags: 766
# 2-redundant tags: 44
# Tags space after Structural Norm.: 625
# Total number of columns: 4865
# MetaDL Size: 1856
# Public+Safety : 50
# MetaDL Size: 1749
# Education : 50
# MetaDL Size: 1766
# Economy : 50
# MetaDL Size: 1624
# Transportation : 50
# MetaDL Size: 2090
# Environment : 50
# MetaDL Size: 2149
# Health : 50
# MetaDL Size: 2371
# Infrastructure : 50
# MetaDL Size: 2796
# Demographics : 50
# MetaDL Size: 1174
# Social+Services : 50
# MetaDL Size: 3057
# Finance : 50
# DL size : 500
# Raw tags space size: 1956
# Tags space after Syntatic Norm.: 1497
# Tags space after Semantic Norm.: 1476
# 1-redundant tags: 848
# 2-redundant tags: 45
# Tags space after Structural Norm.: 583
# Total number of columns: 3538

# %%
generate_output_instances(50)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3097
# Finance : 50
# DL size : 50
# Raw tags space size: 195
# Tags space after Syntatic Norm.: 231
# Tags space after Semantic Norm.: 230
# 1-redundant tags: 191
# 2-redundant tags: 5
# Tags space after Structural Norm.: 34
# Total number of columns: 167
# MetaDL Size: 1183
# Social+Services : 25
# MetaDL Size: 2818
# Demographics : 25
# DL size : 50
# Raw tags space size: 224
# Tags space after Syntatic Norm.: 228
# Tags space after Semantic Norm.: 223
# 1-redundant tags: 144
# 2-redundant tags: 5
# Tags space after Structural Norm.: 74
# Total number of columns: 325
# MetaDL Size: 2396
# Infrastructure : 17
# MetaDL Size: 2157
# Health : 17
# MetaDL Size: 2107
# Environment : 16
# DL size : 50
# Raw tags space size: 240
# Tags space after Syntatic Norm.: 303
# Tags space after Semantic Norm.: 300
# 1-redundant tags: 260
# 2-redundant tags: 1
# Tags space after Structural Norm.: 39
# Total number of columns: 262
# MetaDL Size: 1880
# Public+Safety : 13
# MetaDL Size: 1793
# Education : 13
# MetaDL Size: 1790
# Economy : 12
# MetaDL Size: 1639
# Transportation : 12
# DL size : 50
# Raw tags space size: 348
# Tags space after Syntatic Norm.: 430
# Tags space after Semantic Norm.: 428
# 1-redundant tags: 360
# 2-redundant tags: 7
# Tags space after Structural Norm.: 61
# Total number of columns: 279
# MetaDL Size: 1880
# Public+Safety : 10
# MetaDL Size: 1793
# Education : 10
# MetaDL Size: 1790
# Economy : 10
# MetaDL Size: 1639
# Transportation : 10
# MetaDL Size: 2107
# Environment : 10
# DL size : 50
# Raw tags space size: 225
# Tags space after Syntatic Norm.: 238
# Tags space after Semantic Norm.: 233
# 1-redundant tags: 184
# 2-redundant tags: 5
# Tags space after Structural Norm.: 44
# Total number of columns: 327
# MetaDL Size: 1880
# Public+Safety : 9
# MetaDL Size: 1793
# Education : 9
# MetaDL Size: 1790
# Economy : 8
# MetaDL Size: 1639
# Transportation : 8
# MetaDL Size: 2107
# Environment : 8
# MetaDL Size: 2157
# Health : 8
# DL size : 50
# Raw tags space size: 180
# Tags space after Syntatic Norm.: 196
# Tags space after Semantic Norm.: 187
# 1-redundant tags: 130
# 2-redundant tags: 3
# Tags space after Structural Norm.: 54
# Total number of columns: 347
# MetaDL Size: 1880
# Public+Safety : 8
# MetaDL Size: 1793
# Education : 7
# MetaDL Size: 1790
# Economy : 7
# MetaDL Size: 1639
# Transportation : 7
# MetaDL Size: 2107
# Environment : 7
# MetaDL Size: 2157
# Health : 7
# MetaDL Size: 2396
# Infrastructure : 7
# DL size : 50
# Raw tags space size: 211
# Tags space after Syntatic Norm.: 256
# Tags space after Semantic Norm.: 251
# 1-redundant tags: 155
# 2-redundant tags: 4
# Tags space after Structural Norm.: 92
# Total number of columns: 584
# MetaDL Size: 1880
# Public+Safety : 7
# MetaDL Size: 1793
# Education : 7
# MetaDL Size: 1790
# Economy : 6
# MetaDL Size: 1639
# Transportation : 6
# MetaDL Size: 2107
# Environment : 6
# MetaDL Size: 2157
# Health : 6
# MetaDL Size: 2396
# Infrastructure : 6
# MetaDL Size: 2818
# Demographics : 6
# DL size : 50
# Raw tags space size: 208
# Tags space after Syntatic Norm.: 229
# Tags space after Semantic Norm.: 225
# 1-redundant tags: 177
# 2-redundant tags: 5
# Tags space after Structural Norm.: 43
# Total number of columns: 297
# MetaDL Size: 1880
# Public+Safety : 6
# MetaDL Size: 1793
# Education : 6
# MetaDL Size: 1790
# Economy : 6
# MetaDL Size: 1639
# Transportation : 6
# MetaDL Size: 2107
# Environment : 6
# MetaDL Size: 2157
# Health : 5
# MetaDL Size: 2396
# Infrastructure : 5
# MetaDL Size: 2818
# Demographics : 5
# MetaDL Size: 1183
# Social+Services : 5
# DL size : 50
# Raw tags space size: 233
# Tags space after Syntatic Norm.: 251
# Tags space after Semantic Norm.: 248
# 1-redundant tags: 138
# 2-redundant tags: 1
# Tags space after Structural Norm.: 109
# Total number of columns: 363
# MetaDL Size: 1880
# Public+Safety : 5
# MetaDL Size: 1793
# Education : 5
# MetaDL Size: 1790
# Economy : 5
# MetaDL Size: 1639
# Transportation : 5
# MetaDL Size: 2107
# Environment : 5
# MetaDL Size: 2157
# Health : 5
# MetaDL Size: 2396
# Infrastructure : 5
# MetaDL Size: 2818
# Demographics : 5
# MetaDL Size: 1183
# Social+Services : 5
# MetaDL Size: 3097
# Finance : 5
# DL size : 50
# Raw tags space size: 212
# Tags space after Syntatic Norm.: 254
# Tags space after Semantic Norm.: 252
# 1-redundant tags: 163
# 2-redundant tags: 3
# Tags space after Structural Norm.: 86
# Total number of columns: 302

# %%
generate_output_instances(100) #IRACE
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3096
# Finance : 100
# DL size : 100
# Raw tags space size: 403
# Tags space after Syntatic Norm.: 398
# Tags space after Semantic Norm.: 392
# 1-redundant tags: 286
# 2-redundant tags: 11
# Tags space after Structural Norm.: 95
# Total number of columns: 404
# MetaDL Size: 1183
# Social+Services : 50
# MetaDL Size: 2818
# Demographics : 50
# DL size : 100
# Raw tags space size: 485
# Tags space after Syntatic Norm.: 448
# Tags space after Semantic Norm.: 440
# 1-redundant tags: 250
# 2-redundant tags: 11
# Tags space after Structural Norm.: 179
# Total number of columns: 704
# MetaDL Size: 2396
# Infrastructure : 34
# MetaDL Size: 2157
# Health : 33
# MetaDL Size: 2107
# Environment : 33
# DL size : 100
# Raw tags space size: 453
# Tags space after Syntatic Norm.: 481
# Tags space after Semantic Norm.: 476
# 1-redundant tags: 348
# 2-redundant tags: 9
# Tags space after Structural Norm.: 119
# Total number of columns: 558
# MetaDL Size: 1881
# Public+Safety : 25
# MetaDL Size: 1793
# Education : 25
# MetaDL Size: 1791
# Economy : 25
# MetaDL Size: 1640
# Transportation : 25
# DL size : 100
# Raw tags space size: 519
# Tags space after Syntatic Norm.: 573
# Tags space after Semantic Norm.: 568
# 1-redundant tags: 444
# 2-redundant tags: 15
# Tags space after Structural Norm.: 109
# Total number of columns: 647
# MetaDL Size: 1881
# Public+Safety : 20
# MetaDL Size: 1793
# Education : 20
# MetaDL Size: 1791
# Economy : 20
# MetaDL Size: 1640
# Transportation : 20
# MetaDL Size: 2107
# Environment : 20
# DL size : 100
# Raw tags space size: 419
# Tags space after Syntatic Norm.: 418
# Tags space after Semantic Norm.: 406
# 1-redundant tags: 240
# 2-redundant tags: 11
# Tags space after Structural Norm.: 155
# Total number of columns: 752
# MetaDL Size: 1881
# Public+Safety : 17
# MetaDL Size: 1793
# Education : 17
# MetaDL Size: 1791
# Economy : 17
# MetaDL Size: 1640
# Transportation : 17
# MetaDL Size: 2107
# Environment : 16
# MetaDL Size: 2157
# Health : 16
# DL size : 100
# Raw tags space size: 471
# Tags space after Syntatic Norm.: 480
# Tags space after Semantic Norm.: 470
# 1-redundant tags: 272
# 2-redundant tags: 13
# Tags space after Structural Norm.: 185
# Total number of columns: 775
# MetaDL Size: 1881
# Public+Safety : 15
# MetaDL Size: 1793
# Education : 15
# MetaDL Size: 1791
# Economy : 14
# MetaDL Size: 1640
# Transportation : 14
# MetaDL Size: 2107
# Environment : 14
# MetaDL Size: 2157
# Health : 14
# MetaDL Size: 2396
# Infrastructure : 14
# DL size : 100
# Raw tags space size: 434
# Tags space after Syntatic Norm.: 418
# Tags space after Semantic Norm.: 409
# 1-redundant tags: 224
# 2-redundant tags: 13
# Tags space after Structural Norm.: 172
# Total number of columns: 961
# MetaDL Size: 1881
# Public+Safety : 13
# MetaDL Size: 1793
# Education : 13
# MetaDL Size: 1791
# Economy : 13
# MetaDL Size: 1640
# Transportation : 13
# MetaDL Size: 2107
# Environment : 12
# MetaDL Size: 2157
# Health : 12
# MetaDL Size: 2396
# Infrastructure : 12
# MetaDL Size: 2818
# Demographics : 12
# DL size : 100
# Raw tags space size: 473
# Tags space after Syntatic Norm.: 471
# Tags space after Semantic Norm.: 465
# 1-redundant tags: 282
# 2-redundant tags: 18
# Tags space after Structural Norm.: 165
# Total number of columns: 785
# MetaDL Size: 1881
# Public+Safety : 12
# MetaDL Size: 1793
# Education : 11
# MetaDL Size: 1791
# Economy : 11
# MetaDL Size: 1640
# Transportation : 11
# MetaDL Size: 2107
# Environment : 11
# MetaDL Size: 2157
# Health : 11
# MetaDL Size: 2396
# Infrastructure : 11
# MetaDL Size: 2818
# Demographics : 11
# MetaDL Size: 1183
# Social+Services : 11
# DL size : 100
# Raw tags space size: 772
# Tags space after Syntatic Norm.: 758
# Tags space after Semantic Norm.: 749
# 1-redundant tags: 549
# 2-redundant tags: 12
# Tags space after Structural Norm.: 188
# Total number of columns: 930
# MetaDL Size: 1881
# Public+Safety : 10
# MetaDL Size: 1793
# /usr/local/lib/python3.7/dist-packages/dateutil/parser/_parser.py:1212: UnknownTimezoneWarning: tzname M identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# Education : 10
# MetaDL Size: 1791
# Economy : 10
# MetaDL Size: 1640
# Transportation : 10
# MetaDL Size: 2107
# Environment : 10
# MetaDL Size: 2157
# Health : 10
# MetaDL Size: 2396
# Infrastructure : 10
# MetaDL Size: 2818
# Demographics : 10
# MetaDL Size: 1183
# Social+Services : 10
# MetaDL Size: 3096
# Finance : 10
# DL size : 100
# Raw tags space size: 595
# Tags space after Syntatic Norm.: 582
# Tags space after Semantic Norm.: 579
# 1-redundant tags: 387
# 2-redundant tags: 11
# Tags space after Structural Norm.: 181
# Total number of columns: 932

# %%
generate_output_instances(100)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3095
# Finance : 100
# DL size : 100
# Raw tags space size: 380
# Tags space after Syntatic Norm.: 375
# Tags space after Semantic Norm.: 367
# 1-redundant tags: 248
# 2-redundant tags: 12
# Tags space after Structural Norm.: 107
# Total number of columns: 462
# MetaDL Size: 1183
# Social+Services : 50
# MetaDL Size: 2818
# Demographics : 50
# DL size : 100
# Raw tags space size: 456
# Tags space after Syntatic Norm.: 438
# Tags space after Semantic Norm.: 433
# 1-redundant tags: 235
# 2-redundant tags: 10
# Tags space after Structural Norm.: 188
# Total number of columns: 603
# MetaDL Size: 2396
# Infrastructure : 34
# MetaDL Size: 2157
# Health : 33
# MetaDL Size: 2107
# Environment : 33
# DL size : 100
# Raw tags space size: 456
# Tags space after Syntatic Norm.: 499
# Tags space after Semantic Norm.: 491
# 1-redundant tags: 337
# 2-redundant tags: 11
# Tags space after Structural Norm.: 143
# Total number of columns: 569
# MetaDL Size: 1881
# Public+Safety : 25
# MetaDL Size: 1793
# Education : 25
# MetaDL Size: 1791
# Economy : 25
# MetaDL Size: 1640
# Transportation : 25
# DL size : 100
# Raw tags space size: 472
# Tags space after Syntatic Norm.: 544
# Tags space after Semantic Norm.: 540
# 1-redundant tags: 445
# 2-redundant tags: 7
# Tags space after Structural Norm.: 88
# Total number of columns: 683
# MetaDL Size: 1881
# Public+Safety : 20
# MetaDL Size: 1793
# Education : 20
# MetaDL Size: 1791
# Economy : 20
# MetaDL Size: 1640
# Transportation : 20
# MetaDL Size: 2107
# Environment : 20
# DL size : 100
# Raw tags space size: 399
# Tags space after Syntatic Norm.: 390
# Tags space after Semantic Norm.: 383
# 1-redundant tags: 251
# 2-redundant tags: 12
# Tags space after Structural Norm.: 120
# Total number of columns: 984
# MetaDL Size: 1881
# Public+Safety : 17
# MetaDL Size: 1793
# Education : 17
# MetaDL Size: 1791
# Economy : 17
# MetaDL Size: 1640
# Transportation : 17
# MetaDL Size: 2107
# Environment : 16
# MetaDL Size: 2157
# Health : 16
# DL size : 100
# Raw tags space size: 670
# Tags space after Syntatic Norm.: 630
# Tags space after Semantic Norm.: 622
# 1-redundant tags: 401
# 2-redundant tags: 10
# Tags space after Structural Norm.: 211
# Total number of columns: 1042
# MetaDL Size: 1881
# Public+Safety : 15
# MetaDL Size: 1793
# Education : 15
# MetaDL Size: 1791
# Economy : 14
# MetaDL Size: 1640
# Transportation : 14
# MetaDL Size: 2107
# Environment : 14
# MetaDL Size: 2157
# Health : 14
# MetaDL Size: 2396
# Infrastructure : 14
# DL size : 100
# Raw tags space size: 419
# Tags space after Syntatic Norm.: 414
# Tags space after Semantic Norm.: 407
# 1-redundant tags: 281
# 2-redundant tags: 10
# Tags space after Structural Norm.: 116
# Total number of columns: 595
# MetaDL Size: 1881
# Public+Safety : 13
# MetaDL Size: 1793
# Education : 13
# MetaDL Size: 1791
# Economy : 13
# MetaDL Size: 1640
# Transportation : 13
# MetaDL Size: 2107
# Environment : 12
# MetaDL Size: 2157
# Health : 12
# MetaDL Size: 2396
# Infrastructure : 12
# MetaDL Size: 2818
# Demographics : 12
# DL size : 100
# Raw tags space size: 732
# Tags space after Syntatic Norm.: 738
# Tags space after Semantic Norm.: 728
# 1-redundant tags: 538
# 2-redundant tags: 11
# Tags space after Structural Norm.: 179
# Total number of columns: 871
# MetaDL Size: 1881
# Public+Safety : 12
# MetaDL Size: 1793
# Education : 11
# MetaDL Size: 1791
# Economy : 11
# MetaDL Size: 1640
# Transportation : 11
# MetaDL Size: 2107
# Environment : 11
# MetaDL Size: 2157
# Health : 11
# MetaDL Size: 2396
# Infrastructure : 11
# MetaDL Size: 2818
# Demographics : 11
# MetaDL Size: 1183
# Social+Services : 11
# DL size : 100
# Raw tags space size: 500
# Tags space after Syntatic Norm.: 489
# Tags space after Semantic Norm.: 485
# 1-redundant tags: 307
# 2-redundant tags: 9
# Tags space after Structural Norm.: 169
# Total number of columns: 760
# MetaDL Size: 1881
# Public+Safety : 10
# MetaDL Size: 1793
# Education : 10
# MetaDL Size: 1791
# Economy : 10
# MetaDL Size: 1640
# Transportation : 10
# MetaDL Size: 2107
# Environment : 10
# MetaDL Size: 2157
# Health : 10
# MetaDL Size: 2396
# Infrastructure : 10
# MetaDL Size: 2818
# Demographics : 10
# MetaDL Size: 1183
# Social+Services : 10
# MetaDL Size: 3095
# Finance : 10
# DL size : 100
# Raw tags space size: 510
# Tags space after Syntatic Norm.: 478
# Tags space after Semantic Norm.: 473
# 1-redundant tags: 346
# 2-redundant tags: 15
# Tags space after Structural Norm.: 112
# Total number of columns: 713

# %%
generate_output_instances(300)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3095
# Finance : 300
# DL size : 300
# Raw tags space size: 1092
# Tags space after Syntatic Norm.: 906
# Tags space after Semantic Norm.: 892
# 1-redundant tags: 543
# 2-redundant tags: 35
# Tags space after Structural Norm.: 314
# Total number of columns: 1934
# MetaDL Size: 1183
# Social+Services : 150
# MetaDL Size: 2818
# Demographics : 150
# DL size : 300
# Raw tags space size: 1349
# Tags space after Syntatic Norm.: 1132
# Tags space after Semantic Norm.: 1113
# 1-redundant tags: 688
# 2-redundant tags: 33
# Tags space after Structural Norm.: 392
# Total number of columns: 2258
# MetaDL Size: 2396
# Infrastructure : 100
# MetaDL Size: 2157
# Health : 100
# MetaDL Size: 2107
# Environment : 100
# DL size : 300
# Raw tags space size: 1171
# Tags space after Syntatic Norm.: 1029
# Tags space after Semantic Norm.: 1018
# 1-redundant tags: 570
# 2-redundant tags: 29
# Tags space after Structural Norm.: 419
# Total number of columns: 2228
# MetaDL Size: 1881
# Public+Safety : 75
# MetaDL Size: 1793
# Education : 75
# MetaDL Size: 1791
# Economy : 75
# MetaDL Size: 1640
# Transportation : 75
# DL size : 300
# Raw tags space size: 1304
# Tags space after Syntatic Norm.: 1119
# Tags space after Semantic Norm.: 1102
# 1-redundant tags: 747
# 2-redundant tags: 26
# Tags space after Structural Norm.: 329
# Total number of columns: 2461
# MetaDL Size: 1881
# Public+Safety : 60
# MetaDL Size: 1793
# Education : 60
# MetaDL Size: 1791
# Economy : 60
# MetaDL Size: 1640
# Transportation : 60
# MetaDL Size: 2107
# Environment : 60
# DL size : 300
# Raw tags space size: 1194
# Tags space after Syntatic Norm.: 985
# Tags space after Semantic Norm.: 968
# 1-redundant tags: 542
# 2-redundant tags: 28
# Tags space after Structural Norm.: 398
# Total number of columns: 2903
# MetaDL Size: 1881
# Public+Safety : 50
# MetaDL Size: 1793
# Education : 50
# MetaDL Size: 1791
# Economy : 50
# MetaDL Size: 1640
# Transportation : 50
# MetaDL Size: 2107
# Environment : 50
# MetaDL Size: 2157
# Health : 50
# DL size : 300
# Raw tags space size: 1279
# Tags space after Syntatic Norm.: 1090
# Tags space after Semantic Norm.: 1070
# 1-redundant tags: 562
# 2-redundant tags: 27
# Tags space after Structural Norm.: 481
# Total number of columns: 2784
# MetaDL Size: 1881
# Public+Safety : 43
# MetaDL Size: 1793
# Education : 43
# MetaDL Size: 1791
# Economy : 43
# MetaDL Size: 1640
# Transportation : 43
# MetaDL Size: 2107
# Environment : 43
# MetaDL Size: 2157
# Health : 43
# MetaDL Size: 2396
# Infrastructure : 42
# DL size : 300
# Raw tags space size: 1195
# Tags space after Syntatic Norm.: 985
# Tags space after Semantic Norm.: 970
# 1-redundant tags: 597
# 2-redundant tags: 29
# Tags space after Structural Norm.: 344
# Total number of columns: 2456
# MetaDL Size: 1881
# Public+Safety : 38
# MetaDL Size: 1793
# Education : 38
# MetaDL Size: 1791
# Economy : 38
# MetaDL Size: 1640
# Transportation : 38
# MetaDL Size: 2107
# Environment : 37
# MetaDL Size: 2157
# Health : 37
# MetaDL Size: 2396
# Infrastructure : 37
# MetaDL Size: 2818
# Demographics : 37
# DL size : 300
# Raw tags space size: 1250
# Tags space after Syntatic Norm.: 1032
# Tags space after Semantic Norm.: 1010
# 1-redundant tags: 604
# 2-redundant tags: 35
# Tags space after Structural Norm.: 371
# Total number of columns: 2144
# MetaDL Size: 1881
# Public+Safety : 34
# MetaDL Size: 1793
# Education : 34
# MetaDL Size: 1791
# Economy : 34
# MetaDL Size: 1640
# Transportation : 33
# MetaDL Size: 2107
# Environment : 33
# MetaDL Size: 2157
# Health : 33
# MetaDL Size: 2396
# Infrastructure : 33
# MetaDL Size: 2818
# Demographics : 33
# MetaDL Size: 1183
# Social+Services : 33
# DL size : 300
# Raw tags space size: 1200
# Tags space after Syntatic Norm.: 991
# Tags space after Semantic Norm.: 973
# 1-redundant tags: 565
# 2-redundant tags: 33
# Tags space after Structural Norm.: 375
# Total number of columns: 2344
# MetaDL Size: 1881
# Public+Safety : 30
# MetaDL Size: 1793
# Education : 30
# MetaDL Size: 1791
# Economy : 30
# MetaDL Size: 1640
# Transportation : 30
# MetaDL Size: 2107
# Environment : 30
# MetaDL Size: 2157
# Health : 30
# MetaDL Size: 2396
# Infrastructure : 30
# MetaDL Size: 2818
# Demographics : 30
# MetaDL Size: 1183
# Social+Services : 30
# MetaDL Size: 3095
# Finance : 30
# DL size : 300
# Raw tags space size: 1210
# Tags space after Syntatic Norm.: 1012
# Tags space after Semantic Norm.: 999
# 1-redundant tags: 581
# 2-redundant tags: 39
# Tags space after Structural Norm.: 379
# Total number of columns: 2187

# %%
generate_output_instances(500) #iRace
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3095
# Finance : 500
# DL size : 500
# Raw tags space size: 1600
# Tags space after Syntatic Norm.: 1209
# Tags space after Semantic Norm.: 1189
# 1-redundant tags: 665
# 2-redundant tags: 42
# Tags space after Structural Norm.: 482
# Total number of columns: 3665
# MetaDL Size: 1183
# Social+Services : 250
# MetaDL Size: 2818
# Demographics : 250
# DL size : 500
# Raw tags space size: 1831
# Tags space after Syntatic Norm.: 1434
# Tags space after Semantic Norm.: 1405
# 1-redundant tags: 857
# 2-redundant tags: 49
# Tags space after Structural Norm.: 499
# Total number of columns: 3725
# MetaDL Size: 2396
# Infrastructure : 167
# MetaDL Size: 2157
# Health : 167
# MetaDL Size: 2107
# Environment : 166
# DL size : 500
# Raw tags space size: 1755
# Tags space after Syntatic Norm.: 1399
# Tags space after Semantic Norm.: 1380
# 1-redundant tags: 737
# 2-redundant tags: 36
# Tags space after Structural Norm.: 607
# Total number of columns: 3870
# MetaDL Size: 1881
# Public+Safety : 125
# MetaDL Size: 1793
# Education : 125
# MetaDL Size: 1791
# Economy : 125
# MetaDL Size: 1640
# Transportation : 125
# DL size : 500
# Raw tags space size: 1823
# Tags space after Syntatic Norm.: 1381
# Tags space after Semantic Norm.: 1353
# 1-redundant tags: 763
# 2-redundant tags: 33
# Tags space after Structural Norm.: 557
# Total number of columns: 4647
# MetaDL Size: 1881
# Public+Safety : 100
# MetaDL Size: 1793
# Education : 100
# MetaDL Size: 1791
# Economy : 100
# MetaDL Size: 1640
# Transportation : 100
# MetaDL Size: 2107
# Environment : 100
# DL size : 500
# Raw tags space size: 1720
# Tags space after Syntatic Norm.: 1324
# Tags space after Semantic Norm.: 1306
# 1-redundant tags: 743
# 2-redundant tags: 29
# Tags space after Structural Norm.: 534
# Total number of columns: 3895
# MetaDL Size: 1881
# Public+Safety : 84
# MetaDL Size: 1793
# Education : 84
# MetaDL Size: 1791
# Economy : 83
# MetaDL Size: 1640
# Transportation : 83
# MetaDL Size: 2107
# Environment : 83
# MetaDL Size: 2157
# Health : 83
# DL size : 500
# Raw tags space size: 1900
# Tags space after Syntatic Norm.: 1425
# Tags space after Semantic Norm.: 1408
# 1-redundant tags: 764
# 2-redundant tags: 53
# Tags space after Structural Norm.: 591
# Total number of columns: 4502
# MetaDL Size: 1881
# Public+Safety : 72
# MetaDL Size: 1793
# Education : 72
# MetaDL Size: 1791
# Economy : 72
# MetaDL Size: 1640
# Transportation : 71
# MetaDL Size: 2107
# Environment : 71
# MetaDL Size: 2157
# Health : 71
# MetaDL Size: 2396
# Infrastructure : 71
# DL size : 500
# Raw tags space size: 1745
# Tags space after Syntatic Norm.: 1315
# Tags space after Semantic Norm.: 1291
# 1-redundant tags: 662
# 2-redundant tags: 55
# Tags space after Structural Norm.: 574
# Total number of columns: 4237
# MetaDL Size: 1881
# Public+Safety : 63
# MetaDL Size: 1793
# Education : 63
# MetaDL Size: 1791
# Economy : 63
# MetaDL Size: 1640
# Transportation : 63
# MetaDL Size: 2107
# Environment : 62
# MetaDL Size: 2157
# Health : 62
# MetaDL Size: 2396
# Infrastructure : 62
# MetaDL Size: 2818
# Demographics : 62
# DL size : 500
# Raw tags space size: 1865
# Tags space after Syntatic Norm.: 1457
# Tags space after Semantic Norm.: 1437
# 1-redundant tags: 782
# 2-redundant tags: 50
# Tags space after Structural Norm.: 605
# Total number of columns: 4338
# MetaDL Size: 1881
# Public+Safety : 56
# MetaDL Size: 1793
# Education : 56
# MetaDL Size: 1791
# Economy : 56
# MetaDL Size: 1640
# Transportation : 56
# MetaDL Size: 2107
# Environment : 56
# MetaDL Size: 2157
# Health : 55
# MetaDL Size: 2396
# Infrastructure : 55
# MetaDL Size: 2818
# Demographics : 55
# MetaDL Size: 1183
# Social+Services : 55
# DL size : 500
# Raw tags space size: 1757
# Tags space after Syntatic Norm.: 1307
# Tags space after Semantic Norm.: 1284
# 1-redundant tags: 695
# 2-redundant tags: 47
# Tags space after Structural Norm.: 542
# Total number of columns: 4011
# MetaDL Size: 1881
# Public+Safety : 50
# MetaDL Size: 1793
# Education : 50
# MetaDL Size: 1791
# Economy : 50
# MetaDL Size: 1640
# Transportation : 50
# MetaDL Size: 2107
# Environment : 50
# MetaDL Size: 2157
# Health : 50
# MetaDL Size: 2396
# Infrastructure : 50
# MetaDL Size: 2818
# Demographics : 50
# MetaDL Size: 1183
# Social+Services : 50
# MetaDL Size: 3095
# Finance : 50
# DL size : 500
# Raw tags space size: 1869
# Tags space after Syntatic Norm.: 1428
# Tags space after Semantic Norm.: 1404
# 1-redundant tags: 774
# 2-redundant tags: 51
# Tags space after Structural Norm.: 579
# Total number of columns: 3523

# %%
generate_output_instances(750)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3095
# Finance : 750
# DL size : 750
# Raw tags space size: 2081
# Tags space after Syntatic Norm.: 1467
# Tags space after Semantic Norm.: 1440
# 1-redundant tags: 730
# 2-redundant tags: 58
# Tags space after Structural Norm.: 652
# Total number of columns: 5194
# MetaDL Size: 1183
# Social+Services : 375
# MetaDL Size: 2818
# Demographics : 375
# DL size : 750
# Raw tags space size: 2387
# Tags space after Syntatic Norm.: 1772
# Tags space after Semantic Norm.: 1741
# 1-redundant tags: 1000
# 2-redundant tags: 57
# Tags space after Structural Norm.: 684
# Total number of columns: 5731
# MetaDL Size: 2396
# Infrastructure : 250
# MetaDL Size: 2157
# Health : 250
# MetaDL Size: 2107
# Environment : 250
# DL size : 750
# Raw tags space size: 2461
# Tags space after Syntatic Norm.: 1781
# Tags space after Semantic Norm.: 1759
# 1-redundant tags: 907
# 2-redundant tags: 46
# Tags space after Structural Norm.: 806
# Total number of columns: 5709
# MetaDL Size: 1881
# Public+Safety : 188
# MetaDL Size: 1793
# Education : 188
# MetaDL Size: 1791
# Economy : 187
# MetaDL Size: 1640
# Transportation : 187
# DL size : 750
# Raw tags space size: 2202
# Tags space after Syntatic Norm.: 1605
# Tags space after Semantic Norm.: 1580
# 1-redundant tags: 894
# 2-redundant tags: 47
# Tags space after Structural Norm.: 639
# Total number of columns: 6627
# MetaDL Size: 1881
# Public+Safety : 150
# MetaDL Size: 1793
# Education : 150
# MetaDL Size: 1791
# Economy : 150
# MetaDL Size: 1640
# Transportation : 150
# MetaDL Size: 2107
# Environment : 150
# DL size : 750
# Raw tags space size: 2214
# Tags space after Syntatic Norm.: 1559
# Tags space after Semantic Norm.: 1534
# 1-redundant tags: 737
# 2-redundant tags: 63
# Tags space after Structural Norm.: 734
# Total number of columns: 7124
# MetaDL Size: 1881
# Public+Safety : 125
# MetaDL Size: 1793
# Education : 125
# MetaDL Size: 1791
# Economy : 125
# MetaDL Size: 1640
# Transportation : 125
# MetaDL Size: 2107
# Environment : 125
# MetaDL Size: 2157
# Health : 125
# DL size : 750
# Raw tags space size: 2471
# Tags space after Syntatic Norm.: 1753
# Tags space after Semantic Norm.: 1724
# 1-redundant tags: 876
# 2-redundant tags: 58
# Tags space after Structural Norm.: 790
# Total number of columns: 6852
# MetaDL Size: 1881
# Public+Safety : 108
# MetaDL Size: 1793
# Education : 107
# MetaDL Size: 1791
# Economy : 107
# MetaDL Size: 1640
# Transportation : 107
# MetaDL Size: 2107
# Environment : 107
# MetaDL Size: 2157
# Health : 107
# MetaDL Size: 2396
# Infrastructure : 107
# DL size : 750
# Raw tags space size: 2582
# Tags space after Syntatic Norm.: 1825
# Tags space after Semantic Norm.: 1797
# 1-redundant tags: 876
# 2-redundant tags: 58
# Tags space after Structural Norm.: 863
# Total number of columns: 6446
# MetaDL Size: 1881
# Public+Safety : 94
# MetaDL Size: 1793
# Education : 94
# MetaDL Size: 1791
# Economy : 94
# MetaDL Size: 1640
# Transportation : 94
# MetaDL Size: 2107
# Environment : 94
# MetaDL Size: 2157
# Health : 94
# MetaDL Size: 2396
# Infrastructure : 93
# MetaDL Size: 2818
# Demographics : 93
# DL size : 750
# Raw tags space size: 2621
# Tags space after Syntatic Norm.: 1802
# Tags space after Semantic Norm.: 1775
# 1-redundant tags: 882
# 2-redundant tags: 55
# Tags space after Structural Norm.: 838
# Total number of columns: 6870
# MetaDL Size: 1881
# Public+Safety : 84
# MetaDL Size: 1793
# Education : 84
# MetaDL Size: 1791
# Economy : 84
# MetaDL Size: 1640
# Transportation : 83
# MetaDL Size: 2107
# Environment : 83
# MetaDL Size: 2157
# Health : 83
# MetaDL Size: 2396
# Infrastructure : 83
# MetaDL Size: 2818
# Demographics : 83
# MetaDL Size: 1183
# Social+Services : 83
# DL size : 750
# Raw tags space size: 2463
# Tags space after Syntatic Norm.: 1742
# Tags space after Semantic Norm.: 1709
# 1-redundant tags: 874
# 2-redundant tags: 64
# Tags space after Structural Norm.: 771
# Total number of columns: 6158
# MetaDL Size: 1881
# Public+Safety : 75
# MetaDL Size: 1793
# Education : 75
# MetaDL Size: 1791
# Economy : 75
# MetaDL Size: 1640
# Transportation : 75
# MetaDL Size: 2107
# Environment : 75
# MetaDL Size: 2157
# Health : 75
# MetaDL Size: 2396
# Infrastructure : 75
# MetaDL Size: 2818
# Demographics : 75
# MetaDL Size: 1183
# Social+Services : 75
# MetaDL Size: 3095
# Finance : 75
# DL size : 750
# Raw tags space size: 2672
# Tags space after Syntatic Norm.: 1948
# Tags space after Semantic Norm.: 1903
# 1-redundant tags: 1037
# 2-redundant tags: 66
# Tags space after Structural Norm.: 800
# Total number of columns: 5936

# %%
black_list = generate_output_instances(1000)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3095
# /usr/local/lib/python3.7/dist-packages/dateutil/parser/_parser.py:1212: UnknownTimezoneWarning: tzname M identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# Finance : 1000
# DL size : 1000
# Raw tags space size: 2556
# Tags space after Syntatic Norm.: 1708
# Tags space after Semantic Norm.: 1676
# 1-redundant tags: 820
# 2-redundant tags: 84
# Tags space after Structural Norm.: 772
# Total number of columns: 6995
# MetaDL Size: 1183
# Social+Services : 500
# MetaDL Size: 2818
# Demographics : 500
# DL size : 1000
# Raw tags space size: 2778
# Tags space after Syntatic Norm.: 1971
# Tags space after Semantic Norm.: 1936
# 1-redundant tags: 1075
# 2-redundant tags: 68
# Tags space after Structural Norm.: 793
# Total number of columns: 7755
# MetaDL Size: 2396
# Infrastructure : 334
# MetaDL Size: 2157
# Health : 333
# MetaDL Size: 2107
# Environment : 333
# DL size : 1000
# Raw tags space size: 2999
# Tags space after Syntatic Norm.: 2078
# Tags space after Semantic Norm.: 2050
# 1-redundant tags: 1070
# 2-redundant tags: 57
# Tags space after Structural Norm.: 923
# Total number of columns: 7569
# MetaDL Size: 1881
# Public+Safety : 250
# MetaDL Size: 1793
# Education : 250
# MetaDL Size: 1791
# Economy : 250
# MetaDL Size: 1640
# Transportation : 250
# DL size : 1000
# Raw tags space size: 2623
# Tags space after Syntatic Norm.: 1813
# Tags space after Semantic Norm.: 1784
# 1-redundant tags: 911
# 2-redundant tags: 65
# Tags space after Structural Norm.: 808
# Total number of columns: 9367
# MetaDL Size: 1881
# Public+Safety : 200
# MetaDL Size: 1793
# Education : 200
# MetaDL Size: 1791
# Economy : 200
# MetaDL Size: 1640
# Transportation : 200
# MetaDL Size: 2107
# Environment : 200
# DL size : 1000
# Raw tags space size: 2854
# Tags space after Syntatic Norm.: 1904
# Tags space after Semantic Norm.: 1874
# 1-redundant tags: 903
# 2-redundant tags: 72
# Tags space after Structural Norm.: 899
# Total number of columns: 9512
# MetaDL Size: 1881
# Public+Safety : 167
# MetaDL Size: 1793
# Education : 167
# MetaDL Size: 1791
# Economy : 167
# MetaDL Size: 1640
# Transportation : 167
# MetaDL Size: 2107
# Environment : 166
# MetaDL Size: 2157
# Health : 166
# DL size : 1000
# Raw tags space size: 3017
# Tags space after Syntatic Norm.: 2016
# Tags space after Semantic Norm.: 1983
# 1-redundant tags: 897
# 2-redundant tags: 53
# Tags space after Structural Norm.: 1033
# Total number of columns: 9460
# MetaDL Size: 1881
# Public+Safety : 143
# MetaDL Size: 1793
# Education : 143
# MetaDL Size: 1791
# Economy : 143
# MetaDL Size: 1640
# Transportation : 143
# MetaDL Size: 2107
# Environment : 143
# MetaDL Size: 2157
# Health : 143
# MetaDL Size: 2396
# Infrastructure : 142
# DL size : 1000
# Raw tags space size: 3386
# Tags space after Syntatic Norm.: 2315
# Tags space after Semantic Norm.: 2281
# 1-redundant tags: 1200
# 2-redundant tags: 83
# Tags space after Structural Norm.: 998
# Total number of columns: 8333
# MetaDL Size: 1881
# Public+Safety : 125
# MetaDL Size: 1793
# Education : 125
# MetaDL Size: 1791
# Economy : 125
# MetaDL Size: 1640
# Transportation : 125
# MetaDL Size: 2107
# Environment : 125
# MetaDL Size: 2157
# Health : 125
# MetaDL Size: 2396
# Infrastructure : 125
# MetaDL Size: 2818
# Demographics : 125
# DL size : 1000
# Raw tags space size: 3306
# Tags space after Syntatic Norm.: 2200
# Tags space after Semantic Norm.: 2169
# 1-redundant tags: 1092
# 2-redundant tags: 67
# Tags space after Structural Norm.: 1010
# Total number of columns: 9305
# MetaDL Size: 1881
# Public+Safety : 112
# MetaDL Size: 1793
# Education : 111
# MetaDL Size: 1791
# Economy : 111
# MetaDL Size: 1640
# Transportation : 111
# MetaDL Size: 2107
# Environment : 111
# MetaDL Size: 2157
# Health : 111
# MetaDL Size: 2396
# Infrastructure : 111
# MetaDL Size: 2818
# Demographics : 111
# MetaDL Size: 1183
# Social+Services : 111
# DL size : 1000
# Raw tags space size: 3072
# Tags space after Syntatic Norm.: 2092
# Tags space after Semantic Norm.: 2052
# 1-redundant tags: 1077
# 2-redundant tags: 81
# Tags space after Structural Norm.: 894
# Total number of columns: 7646
# MetaDL Size: 1881
# Public+Safety : 100
# MetaDL Size: 1793
# Education : 100
# MetaDL Size: 1791
# Economy : 100
# MetaDL Size: 1640
# Transportation : 72
# MetaDL Size: 2107
# Environment : 100
# MetaDL Size: 2157
# Health : 100
# MetaDL Size: 2396
# Infrastructure : 100
# MetaDL Size: 2818
# Demographics : 100
# MetaDL Size: 1183
# Social+Services : 100
# MetaDL Size: 3095
# Finance : 100
# DL size : 972
# Raw tags space size: 3182
# Tags space after Syntatic Norm.: 2142
# Tags space after Semantic Norm.: 2104
# 1-redundant tags: 1092
# 2-redundant tags: 68
# Tags space after Structural Norm.: 944
# Total number of columns: 8041

# %%
generate_output_instances(10)
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3095
# Finance : 10
# DL size : 10
# Raw tags space size: 36
# Tags space after Syntatic Norm.: 51
# Tags space after Semantic Norm.: 51
# 1-redundant tags: 33
# 2-redundant tags: 0
# Tags space after Structural Norm.: 18
# Total number of columns: 34
# MetaDL Size: 1183
# Social+Services : 5
# MetaDL Size: 2818
# Demographics : 5
# DL size : 10
# Raw tags space size: 42
# Tags space after Syntatic Norm.: 51
# Tags space after Semantic Norm.: 51
# 1-redundant tags: 43
# 2-redundant tags: 0
# Tags space after Structural Norm.: 8
# Total number of columns: 34
# MetaDL Size: 2396
# Infrastructure : 4
# MetaDL Size: 2157
# Health : 3
# MetaDL Size: 2107
# Environment : 3
# DL size : 10
# Raw tags space size: 20
# Tags space after Syntatic Norm.: 36
# Tags space after Semantic Norm.: 36
# 1-redundant tags: 30
# 2-redundant tags: 0
# Tags space after Structural Norm.: 6
# Total number of columns: 35
# MetaDL Size: 1881
# Public+Safety : 3
# MetaDL Size: 1793
# Education : 3
# MetaDL Size: 1791
# Economy : 2
# MetaDL Size: 1640
# Transportation : 2
# DL size : 10
# Raw tags space size: 27
# Tags space after Syntatic Norm.: 39
# Tags space after Semantic Norm.: 39
# 1-redundant tags: 30
# 2-redundant tags: 0
# Tags space after Structural Norm.: 9
# Total number of columns: 57
# MetaDL Size: 1881
# Public+Safety : 2
# MetaDL Size: 1793
# Education : 2
# MetaDL Size: 1791
# Economy : 2
# MetaDL Size: 1640
# Transportation : 2
# MetaDL Size: 2107
# Environment : 2
# DL size : 10
# Raw tags space size: 148
# Tags space after Syntatic Norm.: 199
# Tags space after Semantic Norm.: 199
# 1-redundant tags: 186
# 2-redundant tags: 0
# Tags space after Structural Norm.: 13
# Total number of columns: 86
# MetaDL Size: 1881
# Public+Safety : 2
# MetaDL Size: 1793
# Education : 2
# MetaDL Size: 1791
# Economy : 2
# MetaDL Size: 1640
# Transportation : 2
# MetaDL Size: 2107
# Environment : 1
# MetaDL Size: 2157
# Health : 1
# DL size : 10
# Raw tags space size: 36
# Tags space after Syntatic Norm.: 54
# Tags space after Semantic Norm.: 54
# 1-redundant tags: 45
# 2-redundant tags: 0
# Tags space after Structural Norm.: 9
# Total number of columns: 40
# MetaDL Size: 1881
# Public+Safety : 2
# MetaDL Size: 1793
# Education : 2
# MetaDL Size: 1791
# Economy : 2
# MetaDL Size: 1640
# Transportation : 1
# MetaDL Size: 2107
# Environment : 1
# MetaDL Size: 2157
# Health : 1
# MetaDL Size: 2396
# Infrastructure : 1
# DL size : 10
# Raw tags space size: 41
# Tags space after Syntatic Norm.: 43
# Tags space after Semantic Norm.: 43
# 1-redundant tags: 19
# 2-redundant tags: 1
# Tags space after Structural Norm.: 23
# Total number of columns: 61
# MetaDL Size: 1881
# Public+Safety : 2
# MetaDL Size: 1793
# Education : 2
# MetaDL Size: 1791
# Economy : 1
# MetaDL Size: 1640
# Transportation : 1
# MetaDL Size: 2107
# Environment : 1
# MetaDL Size: 2157
# Health : 1
# MetaDL Size: 2396
# Infrastructure : 1
# MetaDL Size: 2818
# Demographics : 1
# DL size : 10
# Raw tags space size: 101
# Tags space after Syntatic Norm.: 144
# Tags space after Semantic Norm.: 144
# 1-redundant tags: 135
# 2-redundant tags: 0
# Tags space after Structural Norm.: 9
# Total number of columns: 34
# MetaDL Size: 1881
# Public+Safety : 2
# MetaDL Size: 1793
# Education : 1
# MetaDL Size: 1791
# Economy : 1
# MetaDL Size: 1640
# Transportation : 1
# MetaDL Size: 2107
# Environment : 1
# MetaDL Size: 2157
# Health : 1
# MetaDL Size: 2396
# Infrastructure : 1
# MetaDL Size: 2818
# Demographics : 1
# MetaDL Size: 1183
# Social+Services : 1
# DL size : 10
# Raw tags space size: 158
# Tags space after Syntatic Norm.: 214
# Tags space after Semantic Norm.: 214
# 1-redundant tags: 204
# 2-redundant tags: 1
# Tags space after Structural Norm.: 9
# Total number of columns: 34
# MetaDL Size: 1881
# Public+Safety : 1
# MetaDL Size: 1793
# Education : 1
# MetaDL Size: 1791
# Economy : 1
# MetaDL Size: 1640
# Transportation : 1
# MetaDL Size: 2107
# Environment : 1
# MetaDL Size: 2157
# Health : 1
# MetaDL Size: 2396
# Infrastructure : 1
# MetaDL Size: 2818
# Demographics : 1
# MetaDL Size: 1183
# Social+Services : 1
# MetaDL Size: 3095
# Finance : 1
# DL size : 10
# Raw tags space size: 146
# Tags space after Syntatic Norm.: 202
# Tags space after Semantic Norm.: 202
# 1-redundant tags: 193
# 2-redundant tags: 1
# Tags space after Structural Norm.: 8
# Total number of columns: 40

# %%
generate_output_instances(1000) #IRACE
# Out:
# [['Finance'], ['Social+Services', 'Demographics'], ['Infrastructure', 'Health', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services'], ['Public+Safety', 'Education', 'Economy', 'Transportation', 'Environment', 'Health', 'Infrastructure', 'Demographics', 'Social+Services', 'Finance']]
# MetaDL Size: 3057
# /usr/local/lib/python3.7/dist-packages/dateutil/parser/_parser.py:1212: UnknownTimezoneWarning: tzname M identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# Finance : 1000
# DL size : 1000
# Raw tags space size: 2543
# Tags space after Syntatic Norm.: 1695
# Tags space after Semantic Norm.: 1663
# 1-redundant tags: 817
# 2-redundant tags: 78
# Tags space after Structural Norm.: 768
# Total number of columns: 7238
# MetaDL Size: 1174
# Social+Services : 500
# MetaDL Size: 2796
# Demographics : 500
# DL size : 1000
# Raw tags space size: 2800
# Tags space after Syntatic Norm.: 1992
# Tags space after Semantic Norm.: 1957
# 1-redundant tags: 1094
# 2-redundant tags: 70
# Tags space after Structural Norm.: 793
# Total number of columns: 7531
# MetaDL Size: 2371
# Infrastructure : 334
# MetaDL Size: 2149
# Health : 333
# MetaDL Size: 2090
# Environment : 333
# DL size : 1000
# Raw tags space size: 2968
# Tags space after Syntatic Norm.: 2048
# Tags space after Semantic Norm.: 2022
# 1-redundant tags: 1033
# 2-redundant tags: 60
# Tags space after Structural Norm.: 929
# Total number of columns: 7750
# MetaDL Size: 1856
# Public+Safety : 250
# MetaDL Size: 1749
# Education : 250
# MetaDL Size: 1766
# Economy : 250
# MetaDL Size: 1624
# Transportation : 250
# DL size : 1000
# Raw tags space size: 2678
# Tags space after Syntatic Norm.: 1842
# Tags space after Semantic Norm.: 1816
# 1-redundant tags: 922
# 2-redundant tags: 67
# Tags space after Structural Norm.: 827
# Total number of columns: 9462
# MetaDL Size: 1856
# Public+Safety : 200
# MetaDL Size: 1749
# Education : 200
# MetaDL Size: 1766
# Economy : 200
# MetaDL Size: 1624
# Transportation : 200
# MetaDL Size: 2090
# Environment : 200
# DL size : 1000
# Raw tags space size: 2810
# Tags space after Syntatic Norm.: 1883
# Tags space after Semantic Norm.: 1850
# 1-redundant tags: 913
# 2-redundant tags: 63
# Tags space after Structural Norm.: 874
# Total number of columns: 8867
# MetaDL Size: 1856
# Public+Safety : 167
# MetaDL Size: 1749
# Education : 167
# MetaDL Size: 1766
# Economy : 167
# MetaDL Size: 1624
# Transportation : 167
# MetaDL Size: 2090
# Environment : 166
# MetaDL Size: 2149
# Health : 166
# DL size : 1000
# Raw tags space size: 3120
# Tags space after Syntatic Norm.: 2074
# Tags space after Semantic Norm.: 2045
# 1-redundant tags: 976
# 2-redundant tags: 72
# Tags space after Structural Norm.: 997
# Total number of columns: 9361
# MetaDL Size: 1856
# Public+Safety : 143
# MetaDL Size: 1749
# Education : 143
# MetaDL Size: 1766
# Economy : 143
# MetaDL Size: 1624
# Transportation : 143
# MetaDL Size: 2090
# Environment : 143
# MetaDL Size: 2149
# Health : 143
# MetaDL Size: 2371
# Infrastructure : 142
# DL size : 1000
# Raw tags space size: 3299
# Tags space after Syntatic Norm.: 2260
# Tags space after Semantic Norm.: 2229
# 1-redundant tags: 1198
# 2-redundant tags: 83
# Tags space after Structural Norm.: 948
# Total number of columns: 8809
# MetaDL Size: 1856
# Public+Safety : 125
# MetaDL Size: 1749
# Education : 125
# MetaDL Size: 1766
# Economy : 125
# MetaDL Size: 1624
# Transportation : 125
# MetaDL Size: 2090
# Environment : 125
# MetaDL Size: 2149
# Health : 125
# MetaDL Size: 2371
# Infrastructure : 125
# MetaDL Size: 2796
# Demographics : 125
# DL size : 1000
# Raw tags space size: 3190
# Tags space after Syntatic Norm.: 2157
# Tags space after Semantic Norm.: 2126
# 1-redundant tags: 1026
# 2-redundant tags: 68
# Tags space after Structural Norm.: 1032
# Total number of columns: 9118
# MetaDL Size: 1856
# Public+Safety : 112
# MetaDL Size: 1749
# Education : 111
# MetaDL Size: 1766
# Economy : 111
# MetaDL Size: 1624
# Transportation : 111
# MetaDL Size: 2090
# Environment : 111
# MetaDL Size: 2149
# Health : 111
# MetaDL Size: 2371
# Infrastructure : 111
# MetaDL Size: 2796
# Demographics : 111
# MetaDL Size: 1174
# Social+Services : 111
# DL size : 1000
# Raw tags space size: 3166
# Tags space after Syntatic Norm.: 2137
# Tags space after Semantic Norm.: 2098
# 1-redundant tags: 1135
# 2-redundant tags: 79
# Tags space after Structural Norm.: 884
# Total number of columns: 7581
# MetaDL Size: 1856
# Public+Safety : 100
# MetaDL Size: 1749
# Education : 100
# MetaDL Size: 1766
# Economy : 100
# MetaDL Size: 1624
# Transportation : 62
# MetaDL Size: 2090
# Environment : 100
# MetaDL Size: 2149
# Health : 100
# MetaDL Size: 2371
# Infrastructure : 100
# MetaDL Size: 2796
# Demographics : 100
# MetaDL Size: 1174
# Social+Services : 100
# MetaDL Size: 3057
# Finance : 100
# DL size : 962
# Raw tags space size: 3112
# Tags space after Syntatic Norm.: 2115
# Tags space after Semantic Norm.: 2071
# 1-redundant tags: 1065
# 2-redundant tags: 76
# Tags space after Structural Norm.: 930
# Total number of columns: 7494
